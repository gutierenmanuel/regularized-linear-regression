# %% [markdown]
# ## Statistical Description

# %%
#Importamos y guardamos el dataframe

import pandas as pd

RUTA_DATAFRAME = '/media/tr4shhh/Tr4Shhh_FOLDER/Proyects/4geeks/15_Regresion_lineal_regularizada/regularized-linear-regression/data/interim/demographic_best_columns.csv'

df = pd.read_csv(RUTA_DATAFRAME, sep=',')

# %%
df
# Out:
#       % White-alone  % Black-alone  R_death_2018  \
# 0         76.725239      19.630942           9.6
# 1         87.285228       8.940382          10.3
# 2         49.069571      48.398376          12.9
# 3         76.834821      21.294643          11.4
# 4         95.878285       1.642462          11.4
# ...             ...            ...           ...
# 3135      93.835219       1.375113           7.0
# 3136      95.190850       0.758199           3.2
# 3137      95.354451       0.827627           7.2
# 3138      94.483196       0.507292          10.7
# 3139      93.081671       0.688962           9.7
#
#       Percent of adults with less than a high school diploma 2014-18  \
# 0                                                  11.3
# 1                                                   9.7
# 2                                                  27.0
# 3                                                  16.8
# 4                                                  19.8
# ...                                                 ...
# 3135                                                9.0
# 3136                                                5.6
# 3137                                                7.2
# 3138                                               10.4
# 3139                                                7.8
#
#       Percent of adults with a high school diploma only 2014-18  \
# 0                                                  32.6
# 1                                                  27.6
# 2                                                  35.7
# 3                                                  47.3
# 4                                                  34.0
# ...                                                 ...
# 3135                                               33.3
# 3136                                               13.2
# 3137                                               40.1
# 3138                                               30.3
# 3139                                               35.8
#
#       Percent of adults with a bachelor's degree or higher 2014-18  \
# 0                                                  27.7
# 1                                                  31.3
# 2                                                  12.2
# 3                                                  11.5
# 4                                                  12.6
# ...                                                 ...
# 3135                                               22.0
# 3136                                               57.4
# 3137                                               15.4
# 3138                                               21.5
# 3139                                               19.2
#
#       PCTPOVALL_2018  PCTPOV017_2018  PCTPOV517_2018  MEDHHINC_2018  ...  \
# 0               13.8            19.3            19.5        59338.0  ...
# 1                9.8            13.9            13.1        57588.0  ...
# 2               30.9            43.9            36.7        34382.0  ...
# 3               21.8            27.8            26.3        46064.0  ...
# 4               13.2            18.0            15.5        50412.0  ...
# ...              ...             ...             ...            ...  ...
# 3135             8.4            10.0             8.5        73315.0  ...
# 3136             6.3             6.7             5.9        99087.0  ...
# 3137            10.0            12.1            10.6        63401.0  ...
# 3138            11.9            16.1            14.5        55190.0  ...
# 3139            11.8            16.1            14.2        54319.0  ...
#
#       Heart disease_Upper 95% CI  COPD_prevalence  COPD_Lower 95% CI  \
# 0                            8.7              8.6                7.3
# 1                            8.7              8.6                7.2
# 2                           11.8             12.1               10.7
# 3                            9.3             10.0                8.8
# 4                           10.1             10.5                9.1
# ...                          ...              ...                ...
# 3135                         6.4              6.6                5.7
# 3136                         5.8              4.9                4.0
# 3137                         7.9              8.0                7.0
# 3138                         9.0              8.3                7.1
# 3139                         9.4              8.7                7.3
#
#       COPD_Upper 95% CI  diabetes_Lower 95% CI  diabetes_Upper 95% CI  \
# 0                   9.9                   11.9                   13.8
# 1                  10.1                   11.0                   13.1
# 2                  13.3                   18.6                   20.6
# 3                  11.3                   13.2                   14.9
# 4                  12.0                   12.6                   14.5
# ...                 ...                    ...                    ...
# 3135                7.7                    8.3                    9.6
# 3136                6.0                    6.5                    8.0
# 3137                9.2                    9.5                   11.2
# 3138                9.6                   10.3                   12.1
# 3139               10.1                   10.7                   12.7
#
#       CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  target
# 0                3.1               2.9               3.3    12.9
# 1                3.2               3.0               3.5    12.0
# 2                4.5               4.2               4.8    19.7
# 3                3.3               3.1               3.6    14.1
# 4                3.4               3.2               3.7    13.5
# ...              ...               ...               ...     ...
# 3135             2.6               2.4               2.8     8.9
# 3136             2.4               2.2               2.6     7.2
# 3137             3.0               2.8               3.2    10.4
# 3138             3.4               3.2               3.7    11.3
# 3139             3.4               3.1               3.6    11.7
#
# [3140 rows x 33 columns]

# %% [markdown]
# ### Null Values Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 33 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   % White-alone                                                   3140 non-null   float64
#  1   % Black-alone                                                   3140 non-null   float64
#  2   R_death_2018                                                    3140 non-null   float64
#  3   Percent of adults with less than a high school diploma 2014-18  3140 non-null   float64
#  4   Percent of adults with a high school diploma only 2014-18       3140 non-null   float64
#  5   Percent of adults with a bachelor's degree or higher 2014-18    3140 non-null   float64
#  6   PCTPOVALL_2018                                                  3140 non-null   float64
#  7   PCTPOV017_2018                                                  3140 non-null   float64
#  8   PCTPOV517_2018                                                  3140 non-null   float64
#  9   MEDHHINC_2018                                                   3140 non-null   float64
#  10  CI90LBINC_2018                                                  3140 non-null   float64
#  11  CI90UBINC_2018                                                  3140 non-null   float64
#  12  Unemployment_rate_2018                                          3140 non-null   float64
#  13  Median_Household_Income_2018                                    3140 non-null   float64
#  14  Med_HH_Income_Percent_of_State_Total_2018                       3140 non-null   float64
#  15  anycondition_prevalence                                         3140 non-null   float64
#  16  anycondition_Lower 95% CI                                       3140 non-null   float64
#  17  anycondition_Upper 95% CI                                       3140 non-null   float64
#  18  Obesity_prevalence                                              3140 non-null   float64
#  19  Obesity_Lower 95% CI                                            3140 non-null   float64
#  20  Obesity_Upper 95% CI                                            3140 non-null   float64
#  21  Heart disease_prevalence                                        3140 non-null   float64
#  22  Heart disease_Lower 95% CI                                      3140 non-null   float64
#  23  Heart disease_Upper 95% CI                                      3140 non-null   float64
#  24  COPD_prevalence                                                 3140 non-null   float64
#  25  COPD_Lower 95% CI                                               3140 non-null   float64
#  26  COPD_Upper 95% CI                                               3140 non-null   float64
#  27  diabetes_Lower 95% CI                                           3140 non-null   float64
#  28  diabetes_Upper 95% CI                                           3140 non-null   float64
#  29  CKD_prevalence                                                  3140 non-null   float64
#  30  CKD_Lower 95% CI                                                3140 non-null   float64
#  31  CKD_Upper 95% CI                                                3140 non-null   float64
#  32  target                                                          3140 non-null   float64
# dtypes: float64(33)
# memory usage: 809.7 KB

# %% [markdown]
# ### Statistical Description

# %%
#descripcion estadistica
df.describe()
# Out:
#        % White-alone  % Black-alone  R_death_2018  \
# count    3140.000000    3140.000000   3140.000000
# mean       84.494109       9.342405     10.365287
# std        16.348987      14.478294      2.687543
# min         3.841985       0.000000      0.000000
# 25%        79.620473       0.867069      8.700000
# 50%        91.410189       2.545440     10.400000
# 75%        95.521727      10.852053     12.200000
# max        99.043785      86.069762     21.900000
#
#        Percent of adults with less than a high school diploma 2014-18  \
# count                                        3140.000000
# mean                                           13.410287
# std                                             6.337847
# min                                             1.200000
# 25%                                             8.800000
# 50%                                            12.100000
# 75%                                            17.200000
# max                                            66.300000
#
#        Percent of adults with a high school diploma only 2014-18  \
# count                                        3140.000000
# mean                                           34.285669
# std                                             7.193125
# min                                             5.500000
# 25%                                            29.800000
# 50%                                            34.600000
# 75%                                            39.300000
# max                                            55.600000
#
#        Percent of adults with a bachelor's degree or higher 2014-18  \
# count                                        3140.000000
# mean                                           21.573121
# std                                             9.434320
# min                                             0.000000
# 25%                                            15.000000
# 50%                                            19.250000
# 75%                                            25.600000
# max                                            78.500000
#
#        PCTPOVALL_2018  PCTPOV017_2018  PCTPOV517_2018  MEDHHINC_2018  ...  \
# count     3140.000000     3140.000000     3140.000000    3140.000000  ...
# mean        15.159459       21.106911       19.882962   52767.083758  ...
# std          6.131874        8.909328        8.778545   13907.992668  ...
# min          0.000000        0.000000        0.000000       0.000000  ...
# 25%         10.800000       14.500000       13.400000   43677.000000  ...
# 50%         14.100000       20.100000       18.800000   50564.500000  ...
# 75%         18.300000       26.300000       24.900000   58822.250000  ...
# max         54.000000       68.300000       66.500000  140382.000000  ...
#
#        Heart disease_Upper 95% CI  COPD_prevalence  COPD_Lower 95% CI  \
# count                 3140.000000      3140.000000        3140.000000
# mean                     9.454395         9.095223           7.835096
# std                      1.920387         2.344965           2.088071
# min                      3.700000         3.500000           2.900000
# 25%                      8.200000         7.300000           6.300000
# 50%                      9.400000         8.900000           7.700000
# 75%                     10.700000        10.600000           9.200000
# max                     16.400000        19.900000          17.700000
#
#        COPD_Upper 95% CI  diabetes_Lower 95% CI  diabetes_Upper 95% CI  \
# count        3140.000000            3140.000000            3140.000000
# mean           10.438567              12.088089              14.053726
# std             2.613920               2.622948               2.824828
# min             4.200000               5.500000               6.700000
# 25%             8.500000              10.300000              12.100000
# 50%            10.300000              11.800000              13.800000
# 75%            12.100000              13.700000              15.900000
# max            22.100000              24.200000              27.000000
#
#        CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI       target
# count     3140.000000       3140.000000       3140.000000  3140.000000
# mean         3.446242          3.207516          3.710478    13.073503
# std          0.568059          0.527740          0.613069     2.724351
# min          1.800000          1.700000          1.900000     6.100000
# 25%          3.100000          2.900000          3.300000    11.200000
# 50%          3.400000          3.200000          3.700000    12.800000
# 75%          3.800000          3.500000          4.100000    14.800000
# max          6.200000          5.800000          6.600000    25.600000
#
# [8 rows x 33 columns]

# %%
#numero de filas y columnas
print(f'Filas: {df.shape[0]}, Columnas : {df.shape[1]}')
# Out:
# Filas: 3140, Columnas : 33

# %%
#nombres columnas
print(df.columns)
# Out:
# Index(['% White-alone', '% Black-alone', 'R_death_2018',
#        'Percent of adults with less than a high school diploma 2014-18',
#        'Percent of adults with a high school diploma only 2014-18',
#        'Percent of adults with a bachelor's degree or higher 2014-18',
#        'PCTPOVALL_2018', 'PCTPOV017_2018', 'PCTPOV517_2018', 'MEDHHINC_2018',
#        'CI90LBINC_2018', 'CI90UBINC_2018', 'Unemployment_rate_2018',
#        'Median_Household_Income_2018',
#        'Med_HH_Income_Percent_of_State_Total_2018', 'anycondition_prevalence',
#        'anycondition_Lower 95% CI', 'anycondition_Upper 95% CI',
#        'Obesity_prevalence', 'Obesity_Lower 95% CI', 'Obesity_Upper 95% CI',
#        'Heart disease_prevalence', 'Heart disease_Lower 95% CI',
#        'Heart disease_Upper 95% CI', 'COPD_prevalence', 'COPD_Lower 95% CI',
#        'COPD_Upper 95% CI', 'diabetes_Lower 95% CI', 'diabetes_Upper 95% CI',
#        'CKD_prevalence', 'CKD_Lower 95% CI', 'CKD_Upper 95% CI', 'target'],
#       dtype='object')

# %%
#valores unicos en cada columna
print(df.nunique())
# Out:
# % White-alone                                                     3139
# % Black-alone                                                     3129
# R_death_2018                                                       163
# Percent of adults with less than a high school diploma 2014-18     311
# Percent of adults with a high school diploma only 2014-18          369
# Percent of adults with a bachelor's degree or higher 2014-18       431
# PCTPOVALL_2018                                                     318
# PCTPOV017_2018                                                     426
# PCTPOV517_2018                                                     420
# MEDHHINC_2018                                                     3033
# CI90LBINC_2018                                                    3028
# CI90UBINC_2018                                                    3016
# Unemployment_rate_2018                                             103
# Median_Household_Income_2018                                      3033
# Med_HH_Income_Percent_of_State_Total_2018                          798
# anycondition_prevalence                                            351
# anycondition_Lower 95% CI                                          330
# anycondition_Upper 95% CI                                          346
# Obesity_prevalence                                                 267
# Obesity_Lower 95% CI                                               262
# Obesity_Upper 95% CI                                               265
# Heart disease_prevalence                                           106
# Heart disease_Lower 95% CI                                          96
# Heart disease_Upper 95% CI                                         115
# COPD_prevalence                                                    137
# COPD_Lower 95% CI                                                  121
# COPD_Upper 95% CI                                                  151
# diabetes_Lower 95% CI                                              157
# diabetes_Upper 95% CI                                              166
# CKD_prevalence                                                      43
# CKD_Lower 95% CI                                                    39
# CKD_Upper 95% CI                                                    46
# target                                                             163
# dtype: int64

# %%
#Valores unicos por columna

numero_minimo = 10

for columna in df.columns:
    # Verifica si la columna tiene menos de 10 valores únicos
    if df[columna].nunique() < numero_minimo:
        # Imprime los valores únicos de la columna 'neighbourhood_group'
        print(f"Valores únicos de {columna}: {df[columna].unique()}")

# %%
#Copiamos el dataframe para no ser destructivos con los datos
clean_df = df.copy()

# %% [markdown]
# ## Univariate Description

# %% [markdown]
# ### Numerical

# %%
#Nos quedamos solo con las variables numericas
numericas = clean_df.select_dtypes(include='number')

# %%
numericas
# Out:
#       % White-alone  % Black-alone  R_death_2018  \
# 0         76.725239      19.630942           9.6
# 1         87.285228       8.940382          10.3
# 2         49.069571      48.398376          12.9
# 3         76.834821      21.294643          11.4
# 4         95.878285       1.642462          11.4
# ...             ...            ...           ...
# 3135      93.835219       1.375113           7.0
# 3136      95.190850       0.758199           3.2
# 3137      95.354451       0.827627           7.2
# 3138      94.483196       0.507292          10.7
# 3139      93.081671       0.688962           9.7
#
#       Percent of adults with less than a high school diploma 2014-18  \
# 0                                                  11.3
# 1                                                   9.7
# 2                                                  27.0
# 3                                                  16.8
# 4                                                  19.8
# ...                                                 ...
# 3135                                                9.0
# 3136                                                5.6
# 3137                                                7.2
# 3138                                               10.4
# 3139                                                7.8
#
#       Percent of adults with a high school diploma only 2014-18  \
# 0                                                  32.6
# 1                                                  27.6
# 2                                                  35.7
# 3                                                  47.3
# 4                                                  34.0
# ...                                                 ...
# 3135                                               33.3
# 3136                                               13.2
# 3137                                               40.1
# 3138                                               30.3
# 3139                                               35.8
#
#       Percent of adults with a bachelor's degree or higher 2014-18  \
# 0                                                  27.7
# 1                                                  31.3
# 2                                                  12.2
# 3                                                  11.5
# 4                                                  12.6
# ...                                                 ...
# 3135                                               22.0
# 3136                                               57.4
# 3137                                               15.4
# 3138                                               21.5
# 3139                                               19.2
#
#       PCTPOVALL_2018  PCTPOV017_2018  PCTPOV517_2018  MEDHHINC_2018  ...  \
# 0               13.8            19.3            19.5        59338.0  ...
# 1                9.8            13.9            13.1        57588.0  ...
# 2               30.9            43.9            36.7        34382.0  ...
# 3               21.8            27.8            26.3        46064.0  ...
# 4               13.2            18.0            15.5        50412.0  ...
# ...              ...             ...             ...            ...  ...
# 3135             8.4            10.0             8.5        73315.0  ...
# 3136             6.3             6.7             5.9        99087.0  ...
# 3137            10.0            12.1            10.6        63401.0  ...
# 3138            11.9            16.1            14.5        55190.0  ...
# 3139            11.8            16.1            14.2        54319.0  ...
#
#       Heart disease_Upper 95% CI  COPD_prevalence  COPD_Lower 95% CI  \
# 0                            8.7              8.6                7.3
# 1                            8.7              8.6                7.2
# 2                           11.8             12.1               10.7
# 3                            9.3             10.0                8.8
# 4                           10.1             10.5                9.1
# ...                          ...              ...                ...
# 3135                         6.4              6.6                5.7
# 3136                         5.8              4.9                4.0
# 3137                         7.9              8.0                7.0
# 3138                         9.0              8.3                7.1
# 3139                         9.4              8.7                7.3
#
#       COPD_Upper 95% CI  diabetes_Lower 95% CI  diabetes_Upper 95% CI  \
# 0                   9.9                   11.9                   13.8
# 1                  10.1                   11.0                   13.1
# 2                  13.3                   18.6                   20.6
# 3                  11.3                   13.2                   14.9
# 4                  12.0                   12.6                   14.5
# ...                 ...                    ...                    ...
# 3135                7.7                    8.3                    9.6
# 3136                6.0                    6.5                    8.0
# 3137                9.2                    9.5                   11.2
# 3138                9.6                   10.3                   12.1
# 3139               10.1                   10.7                   12.7
#
#       CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  target
# 0                3.1               2.9               3.3    12.9
# 1                3.2               3.0               3.5    12.0
# 2                4.5               4.2               4.8    19.7
# 3                3.3               3.1               3.6    14.1
# 4                3.4               3.2               3.7    13.5
# ...              ...               ...               ...     ...
# 3135             2.6               2.4               2.8     8.9
# 3136             2.4               2.2               2.6     7.2
# 3137             3.0               2.8               3.2    10.4
# 3138             3.4               3.2               3.7    11.3
# 3139             3.4               3.1               3.6    11.7
#
# [3140 rows x 33 columns]

# %%
numericas.describe()
# Out:
#        % White-alone  % Black-alone  R_death_2018  \
# count    3140.000000    3140.000000   3140.000000
# mean       84.494109       9.342405     10.365287
# std        16.348987      14.478294      2.687543
# min         3.841985       0.000000      0.000000
# 25%        79.620473       0.867069      8.700000
# 50%        91.410189       2.545440     10.400000
# 75%        95.521727      10.852053     12.200000
# max        99.043785      86.069762     21.900000
#
#        Percent of adults with less than a high school diploma 2014-18  \
# count                                        3140.000000
# mean                                           13.410287
# std                                             6.337847
# min                                             1.200000
# 25%                                             8.800000
# 50%                                            12.100000
# 75%                                            17.200000
# max                                            66.300000
#
#        Percent of adults with a high school diploma only 2014-18  \
# count                                        3140.000000
# mean                                           34.285669
# std                                             7.193125
# min                                             5.500000
# 25%                                            29.800000
# 50%                                            34.600000
# 75%                                            39.300000
# max                                            55.600000
#
#        Percent of adults with a bachelor's degree or higher 2014-18  \
# count                                        3140.000000
# mean                                           21.573121
# std                                             9.434320
# min                                             0.000000
# 25%                                            15.000000
# 50%                                            19.250000
# 75%                                            25.600000
# max                                            78.500000
#
#        PCTPOVALL_2018  PCTPOV017_2018  PCTPOV517_2018  MEDHHINC_2018  ...  \
# count     3140.000000     3140.000000     3140.000000    3140.000000  ...
# mean        15.159459       21.106911       19.882962   52767.083758  ...
# std          6.131874        8.909328        8.778545   13907.992668  ...
# min          0.000000        0.000000        0.000000       0.000000  ...
# 25%         10.800000       14.500000       13.400000   43677.000000  ...
# 50%         14.100000       20.100000       18.800000   50564.500000  ...
# 75%         18.300000       26.300000       24.900000   58822.250000  ...
# max         54.000000       68.300000       66.500000  140382.000000  ...
#
#        Heart disease_Upper 95% CI  COPD_prevalence  COPD_Lower 95% CI  \
# count                 3140.000000      3140.000000        3140.000000
# mean                     9.454395         9.095223           7.835096
# std                      1.920387         2.344965           2.088071
# min                      3.700000         3.500000           2.900000
# 25%                      8.200000         7.300000           6.300000
# 50%                      9.400000         8.900000           7.700000
# 75%                     10.700000        10.600000           9.200000
# max                     16.400000        19.900000          17.700000
#
#        COPD_Upper 95% CI  diabetes_Lower 95% CI  diabetes_Upper 95% CI  \
# count        3140.000000            3140.000000            3140.000000
# mean           10.438567              12.088089              14.053726
# std             2.613920               2.622948               2.824828
# min             4.200000               5.500000               6.700000
# 25%             8.500000              10.300000              12.100000
# 50%            10.300000              11.800000              13.800000
# 75%            12.100000              13.700000              15.900000
# max            22.100000              24.200000              27.000000
#
#        CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI       target
# count     3140.000000       3140.000000       3140.000000  3140.000000
# mean         3.446242          3.207516          3.710478    13.073503
# std          0.568059          0.527740          0.613069     2.724351
# min          1.800000          1.700000          1.900000     6.100000
# 25%          3.100000          2.900000          3.300000    11.200000
# 50%          3.400000          3.200000          3.700000    12.800000
# 75%          3.800000          3.500000          4.100000    14.800000
# max          6.200000          5.800000          6.600000    25.600000
#
# [8 rows x 33 columns]

# %%
#valores unicos en cada columna
print(numericas.nunique())
# Out:
# % White-alone                                                     3139
# % Black-alone                                                     3129
# R_death_2018                                                       163
# Percent of adults with less than a high school diploma 2014-18     311
# Percent of adults with a high school diploma only 2014-18          369
# Percent of adults with a bachelor's degree or higher 2014-18       431
# PCTPOVALL_2018                                                     318
# PCTPOV017_2018                                                     426
# PCTPOV517_2018                                                     420
# MEDHHINC_2018                                                     3033
# CI90LBINC_2018                                                    3028
# CI90UBINC_2018                                                    3016
# Unemployment_rate_2018                                             103
# Median_Household_Income_2018                                      3033
# Med_HH_Income_Percent_of_State_Total_2018                          798
# anycondition_prevalence                                            351
# anycondition_Lower 95% CI                                          330
# anycondition_Upper 95% CI                                          346
# Obesity_prevalence                                                 267
# Obesity_Lower 95% CI                                               262
# Obesity_Upper 95% CI                                               265
# Heart disease_prevalence                                           106
# Heart disease_Lower 95% CI                                          96
# Heart disease_Upper 95% CI                                         115
# COPD_prevalence                                                    137
# COPD_Lower 95% CI                                                  121
# COPD_Upper 95% CI                                                  151
# diabetes_Lower 95% CI                                              157
# diabetes_Upper 95% CI                                              166
# CKD_prevalence                                                      43
# CKD_Lower 95% CI                                                    39
# CKD_Upper 95% CI                                                    46
# target                                                             163
# dtype: int64

# %%
#Valores unicos por columna

numero_minimo = 50

for columna in numericas.columns:
    # Verifica si la columna tiene menos de 10 valores únicos
    if df[columna].nunique() < numero_minimo:
        # Imprime los valores únicos de la columna 'neighbourhood_group'
        print(f"Valores únicos de {columna}: {df[columna].unique()}")
# Out:
# Valores únicos de CKD_prevalence: [3.1 3.2 4.5 3.3 3.4 4.3 3.6 4.  3.9 3.5 4.8 3.8 3.  5.8 4.6 4.1 3.7 2.8
#  5.  4.4 5.3 4.2 2.7 2.3 2.4 2.6 2.2 2.5 2.9 4.7 5.1 5.5 4.9 2.1 1.8 5.9
#  5.2 5.6 2.  6.2 5.4 5.7 1.9]
# Valores únicos de CKD_Lower 95% CI: [2.9 3.  4.2 3.1 3.2 4.1 3.3 3.8 3.6 3.7 4.5 4.  3.5 2.8 3.4 5.4 4.3 2.6
#  4.7 4.9 3.9 2.5 2.7 2.2 2.3 2.1 2.4 4.8 5.1 4.4 4.6 5.  2.  1.7 5.6 5.2
#  1.9 5.8 1.8]
# Valores únicos de CKD_Upper 95% CI: [3.3 3.5 4.8 3.6 3.7 4.6 3.8 4.2 4.3 3.9 5.1 4.1 3.2 6.2 4.4 4.  2.9 5.3
#  4.9 5.6 3.4 4.7 3.  2.5 2.8 2.3 2.6 3.1 5.  5.4 6.  5.2 4.5 2.7 2.4 5.7
#  1.9 6.3 5.9 2.2 6.6 5.8 6.1 5.5 6.4 2. ]

# %% [markdown]
# We can see that all the columns exhibit a normal distribution.

# %%
from utils import plot_numerical_data

plot_numerical_data(numericas)
